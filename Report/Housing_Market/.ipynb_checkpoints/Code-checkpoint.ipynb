# %%
def Adj(Value,Type):
    if Type==1:
        if np.sign(Value)==-1:
            return("negative")
        if np.sign(Value)==1:
            return("positive")
        else:
            return('unchanged')
    if Type==2:
        if np.sign(Value)==-1:
            return("down")
        if np.sign(Value)==1:
            return("up")
        else:
            return('unchanged at')
    if Type==3:
        if np.sign(Value)==-1:
            return("less")
        if np.sign(Value)==1:
            return("more")
        else:
            return('unchanged at')

def Comma(Value):
    return(locale.format_string("%d", Value,-2))

# %%
import os
import pandas as pd
import numpy as np
import locale
locale.setlocale(locale.LC_NUMERIC, 'en_US')

class HousingMarket:
    def __init__(self, month, year, TP1,TP2,TP3,TP4,TP5):
        self.TP1=TP1
        self.TP2=TP2
        self.TP3=TP3
        self.TP4=TP4
        self.TP5=TP5
        self.year=year
        self.month=month
        
    def P1(self):
        S1 = "In " + Month+", sales experienced a "+Adj(TP1["Sales_IL_sells"][3],1)+" annual change, whereas median prices experienced a "+Adj(TP1["Sales_IL_sells"][3],1)+" annual change in both Illinois and Chicago PMSA. "
        S2 =  str(Comma(TP1["Sales_IL_sells"][3]))+ " houses were sold in Illinois, changing by "+ str(TP1["Sales_AGrowthIL"][3].round(1))+"% from a year ago and "+ str(TP1["Sales_MGrowthIL"][3].round(1)) +"% from a month ago."
        S3 = " In the Chicago PMSA, " +str(Comma(TP1["Sales_CH_sells"][3]))+ " houses were sold, changing by " + str(TP1["Sales_AGrowthCH"][3].round(1))+ "% from a year ago and " + str(TP1["Sales_MGrowthCH"][3].round(1)) +"% from a month ago."
        S4 = "The median price was $" +  str(Comma(TP1["Price_IL_price"][3]))+ " in Illinois, changing by " + str(TP1["Price_AGrowthIL"][3].round(1))+" from "+Month+" last year; the comparable figure for the Chicago PMSA was $" + str(Comma(TP1["Price_CH_price"][3]))+", up "+ str(TP1["Price_AGrowthCH"][3].round(1)) +"% from " + Month+ " last year."
        paragraph = S1+S2+S3+S4
        return paragraph
    
    def P2(self):
        S1="In "+Month+", for the Chicago PMSA, the percentage of foreclosed sales (e.g. REOs) among the total sales was "+str(100*TP2["fratio"][3].round(3))+"%. "
        S2=str(Comma(TP2["Regular_Sale"][3].round(1)))+" regular sales were made, "+ str(TP2["RS_AGrowth"][3].round(1)) +"% "+Adj(TP2["RS_AGrowth"][3],3)+" than last year. "+str(Comma(TP2["ForeCProp"][3]))+" foreclosed properties were sold, "+str(TP2["FCP_AGrowth"][3].round(1))+"% "+Adj(TP2["FCP_AGrowth"][3],3)+" than last year."
        S3="The median price was $"+str(Comma(TP2["MedianPrice"][3]))+" for regular property sales, "+Adj(TP2["MP_AGrowth"][3],1)+" "+str(TP2["MP_AGrowth"][3].round(3))+"% from last year; the comparable figure for the foreclosed properties was $"+str(Comma(TP2["MedianPrice_FC"][3]))+", "+Adj(TP2["MPFC_AGrowth"][3],3)+" "+str(TP2["MPFC_AGrowth"][3].round(1))+"% from last year. "
        paragraph = S1+S2+S3
        return paragraph
    
    
    def P3(self):
        S1="The sales forecast for "+PostMonth+", "+PPstMonth+", and "+PPPtMonth+" suggests a decrease on a yearly and monthly basis for both Illinois and the Chicago PMSA. "
        S2="Annually for Illinois, the three-month average forecasts point to a decrease in the range of "+str(TP3["TAGrowthIL_LB"][6].round(3)*100)+" to "+str(TP3["TAGrowthIL_UB"][6].round(3)*100)+"%; the comparative figures for the Chicago PMSA are a decrease in the range of "+str(TP3["TAGrowthCH_LB"][6].round(3)*100)+"% to "+str(TP3["TAGrowthIL_UB"][6].round(3)*100)+"%. "
        S3="On a monthly basis, the three-month average sales are forecast to decrease in the range of "+str(TP3["TMGrowthIL_LB"][6].round(3)*100)+"% to "+str(TP3["TMGrowthIL_UB"][6].round(3)*100)+"% for Illinois and decrease in the range of "+str(TP3["TMGrowthCH_LB"][6].round(3)*100)+"% to "+str(TP3["TMGrowthCH_UB"][6].round(3)*100)+"% for the Chicago PMSA."
        paragraph = S1+S2+S3
        return paragraph
    
    def P4(self):
        S1="The pending home sales index  is a leading indicator based on contract signings."
        S2="This "+Month+", the number of homes put under contract was less than last year in Illinois and Chicago PMSA. "
        S3="The pending home sales index is "+str(TP4["ILpending"][3].round(1))+" (2019=100) in Illinois, down "+str(TP4["pendingGrowthIL"][3].round(1))+"% from a year ago. "
        S4="In the Chicago PMSA, the comparable figure is "+str(TP4["CHpending"][3].round(1))+" down "+str(TP4["pendingGrowthCH"][3].round(1))+"% from a year ago. "  
        S5="At the latest average annual pending sales rate, Illinois had enough housing inventory for 2.0 months (remaining the same as last year) . "
        S6="In the Chicago PMSA, the comparable figure was 2.0 months (remaining the same as last year). "
        S7="The lowest price ranges (<$100K) showed the largest decline both in Illinois, and in the Chicago PMSA."
        paragraph = S1+S2+S3+S4+S5+S6+S7
        return paragraph
        
    def P5(self):
        S1="The median price forecast indicates positive annual growth for "+PostMonth+", "+PPstMonth+", and "+PPPtMonth+" in both Illinois and the Chicago PMSA. "
        S2="In Illinois, the median price is forecast to change by "+str(TP5["AGrowthIL"][4].round(1))+"% in "+PostMonth+", "+str(TP5["AGrowthIL"][5].round(1))+"% in "+PPstMonth+", and "+str(TP5["AGrowthIL"][6].round(1))+"% in "+PPPtMonth+". "
        S3="For the Chicago PMSA, the comparable figures are "+str(TP5["AGrowthCH"][4].round(1))+"% in "+PostMonth+", "+str(TP5["AGrowthCH"][5].round(1))+"% in "+PPstMonth+", and "+str(TP5["AGrowthCH"][6].round(1))+"% in "+PPPtMonth+". "
        S4="As a complement to the median housing price index (HPI), the SHDRE HPI forecasts a positive growth trend for both Illinois and the Chicago PMSA.  "
        S5="In Illinois, the SHDRE HPI (Jan 2008=1) is forecast to change by "+str(TP5["foreCGrowIL"][4].round(3)*100)+"% in "+PostMonth+", "+str(TP5["foreCGrowIL"][5].round(3)*100)+"% in "+PPstMonth+", and "+str(TP5["foreCGrowIL"][6].round(3)*100)+"% in "+PPPtMonth+". "
        S6="The comparable figures for the Chicago PMSA are "+str(TP5["foreCGrowCH"][4].round(3)*100)+"% in "+PostMonth+", "+str(TP5["foreCGrowCH"][5].round(3)*100)+"% in "+PPstMonth+", and "+str(TP5["foreCGrowCH"][6].round(3)*100)+"% in "+PPPtMonth+". "
        S7="SHDRE HPI takes housing characteristics into account and constructs comparable “baskets” of homes for each month."
        paragraph = S1+S2+S3+S4+S5+S6+S7
        return paragraph
        
    def P6(self):
        S1="In "+Month+", the Conference Board Consumer Confidence Index [https://www.conference-board.org/topics/consumer-confidence], whereas the University of Michigan Consumer Sentiment Index [http://www.sca.isr.umich.edu/]. "
        S2="The Conference Board Consumer Confidence Index survey noted that [https://www.conference-board.org/topics/consumer-confidence] "
        S3="The University of Michigan Consumer Sentiment Index survey noted that [http://www.sca.isr.umich.edu/]."
        paragraph = S1+S2+S3
        return paragraph

# %%
import os
import pandas as pd

PreMonth="January"
Month="February"
PostMonth="March"
PPstMonth="April"
PPPtMonth="May"
Year="2023"
PreYear="2023"

os.chdir(r'C:\\Users\\Keitaro Ninomiya\\Box\\IAR_nino\\Results\Talking_Points\\Housing_Market')
TP1=pd.read_csv(Month+Year+"TP1.csv")
TP2=pd.read_csv(Month+Year+"TP2.csv")
TP3=pd.read_csv(Month+Year+"TP3.csv")
TP4=pd.read_csv(Month+Year+"TP4.csv")
TP5=pd.read_csv(Month+Year+"TP5.csv")

Paragraphs=HousingMarket(Month, Year, TP1,TP2,TP3,TP4,TP5)
P1=Paragraphs.P1()
P2=Paragraphs.P2()
P3=Paragraphs.P3()
P4=Paragraphs.P4()
P5=Paragraphs.P5()
P6=Paragraphs.P6()
Draft=((Paragraphs.P1(),Paragraphs.P2(),Paragraphs.P3(),Paragraphs.P4(),Paragraphs.P5(),Paragraphs.P6()))

# %%
os.chdir(r'C:\\Users\\Keitaro Ninomiya\\Box\\IAR_nino\\Report')
textfile = open("Housing_Market"+Month+Year+".txt", "w")
for element in Draft:
    textfile.write(element + "\n")
textfile.close()

# %%
Draft
# Out:
# ('In February, sales experienced a positive annual change, whereas median prices experienced a positive annual change in both Illinois and Chicago PMSA. 7,509 houses were sold in Illinois, changing by -25.1% from a year ago and 10.6% from a month ago. In the Chicago PMSA, 4,982 houses were sold, changing by -29.4% from a year ago and 11.6% from a month ago.The median price was $240,000 in Illinois, changing by 0.0 from February last year; the comparable figure for the Chicago PMSA was $290,000, up 0.0% from February last year.',
#  'In February, for the Chicago PMSA, the percentage of foreclosed sales (e.g. REOs) among the total sales was 6.9%. 4,614 regular sales were made, -31.2% less than last year. 344 foreclosed properties were sold, 12.8% more than last year.The median price was $295,000 for regular property sales, unchanged 0.0% from last year; the comparable figure for the foreclosed properties was $239,000, more 3.5% from last year. ',
# ...
