# %%
def Adj(Value,Type):
    if Type==1:
        if np.sign(Value)==-1:
            return("negative")
        if np.sign(Value)==1:
            return("positive")
        else:
            return('unchanged')
    if Type==2:
        if np.sign(Value)==-1:
            return("down")
        if np.sign(Value)==1:
            return("up")
        else:
            return('unchanged at')
    if Type==3:
        if np.sign(Value)==-1:
            return("less")
        if np.sign(Value)==1:
            return("more")
        else:
            return('unchanged at')
        
    if Type==4:
        if np.sign(Value)==-1:
            return("decrease")
        if np.sign(Value)==1:
            return("increase")
        else:
            return('unchanged')

def Comma(Value):
    return(locale.format_string("%d", Value,-2))

# %%
class HousingMarketFuture:
    def __init__(self, month, year, TP1,TP2,TP3,TP4,TP5):
        self.year=year
        self.month=month
        self.TP1=TP1
        self.TP2=TP2
        self.TP3=TP3
        self.TP4=TP4
        self.TP5=TP5
        
    def P1(self):
        S1="The median price forecast indicates "+Adj(TP1["AGrowthIL"][4],1)+" annual growth for "+PostMonth+", "+PPstMonth+", and "+PPPtMonth+" in Illinois."
        S2="The median price forecast indicates "+Adj(TP1["AGrowthCH"][4],1)+" annual growth for "+PostMonth+", "+PPstMonth+", and "+PPPtMonth+" in the Chicago PMSA. "
        S3="In Illinois, the median price is forecast to change by "+str(TP1["AGrowthCH"][4].round(2))+"% in "+PostMonth+", "+str(TP5["AGrowthIL"][5].round(1))+"% in "+PPstMonth+", and "+str(TP5["AGrowthIL"][6].round(1))+"% in "+PPPtMonth+". "
        S4="For the Chicago PMSA, the comparable figures are "+str(TP5["AGrowthCH"][4].round(1))+"% in "+PostMonth+", "+str(TP1["AGrowthCH"][5].round(2))+"% in "+PPstMonth+", and "+str(TP1["AGrowthCH"][6].round(2))+"% in "+PPPtMonth+". "
        S5="(Reference: Forecast for November 2022 report table) "
        paragraph = S1+S2+S3+S4+S5
        return paragraph
        
    def P2(self):
        S1="As a complement to the median housing price index (HPI), the SHDRE HPI forecasts a "+Adj(TP2["foreCGrowIL"][4].round(2),4)+" growth trend for Illinois."
        S2="As a complement to the median housing price index (HPI), the SHDRE HPI forecasts a "+Adj(TP2["foreCGrowIL"][4].round(2),4)+" growth trend for the Chicago PMSA"
        S3="In Illinois, the SHDRE HPI (Jan 2008=1) is forecast to change by "+str(100*TP2["foreCGrowIL"][4].round(2))+"% in "+PostMonth+", "+str(100*TP2["foreCGrowIL"][5].round(2))+"% in "+PPstMonth+", and "+str(100*TP2["foreCGrowCH"][6].round(2))+"% in "+PPPtMonth+". "
        S4="The comparable figures for the Chicago PMSA are "+str(100*TP2["foreCGrowCH"][4].round(2))+"% in "+PostMonth+", "+str(100*TP2["foreCGrowCH"][5].round(2))+"% in "+PPstMonth+", and "+str(TP5["foreCGrowCH"][6].round(3)*100)+"% in "+PPPtMonth+". "
        S5="SHDRE HPI takes housing characteristics into account and constructs comparable “baskets” of homes for each month."
        S6="(Reference: Housing Price Index)"
        paragraph = S1+S2+S3+S4+S5
        return paragraph
        
    def P3(self):
        S1="The sales forecast for "+PostMonth+", "+PPstMonth+", and "+PPPtMonth+" suggests a decrease on a yearly and monthly basis for both Illinois and the Chicago PMSA. "
        S2="Annually for Illinois, the three-month average forecasts point to a decrease in the range of "+str(100*TP3["TAGrowthIL_LB"][6].round(2))+" to "+str(100*TP3["TAGrowthIL_UB"][6].round(2))+"%; the comparative figures for the Chicago PMSA are a decrease in the range of "+str(100*TP3["TAGrowthCH_LB"][6].round(2))+"% to "+str(100*TP3["TAGrowthIL_UB"][6].round(2))+"%. "
        S3="On a monthly basis, the three-month average sales are forecast to decrease in the range of "+str(100*TP3["TMGrowthIL_LB"][6].round(2))+"% to "+str(100*TP3["TMGrowthIL_UB"][6].round(2))+"% for Illinois and decrease in the range of "+str(100*TP3["TMGrowthCH_LB"][6].round(2))+"% to "+str(100*TP3["TMGrowthCH_UB"][6].round(2))+"% for the Chicago PMSA."
        S4="(Reference: Forecast for "+Month+" 2022 report table)"
        paragraph = S1+S2+S3+S4
        return paragraph
                
    def P4(self):
        S1="The pending home sales index  is a leading indicator based on contract signings."
        S2="This October, the number of homes put under contract was less than last year in Illinois and Chicago PMSA. "
        S3="The pending home sales index is "+str(TP4["ILpending"][3].round(2))+" (2019=100) in Illinois, down "+str(100*TP4["pendingGrowthIL"][3].round(2))+"% from a year ago. "
        S4="In the Chicago PMSA, the comparable figure is "+str(TP4["CHpending"][3].round(2))+" down "+str(TP4["pendingGrowthCH"][3].round(2))+"% from a year ago. "  
        S5="(Reference: Illinois and Chicago PMSA Pending Home Sales Index figure)"
        paragraph = S1+S2+S3+S4
        return paragraph        
        
    def P5(self):
        S1="In December 2022, "+str(TP5["in_count"][3])+" houses were newly filed for foreclosure in the Chicago PMSA (up "+str(100*TP5["in_rateyear"][3].round(2))+"% and down "+str(100*TP5["in_ratemon"][3].round(2))+"%, respectively, from a year and a month ago). "
        S2=str(TP5["out_count"][3])+" foreclosures were completed (up "+str(100*TP5["out_rateyear"][3].round(2))+"% and up "+str(100*TP5["out_ratemon"][3].round(2))+"% respectively from a year and a month ago).  "
        S3="As of December 2022, there are "+str(FI)+" homes at some stage of foreclosure — the foreclosure inventory. "
        S4="The monthly average net flows of foreclosures (foreclosure inflows - outflows) were "+str(FI6)+" in the past 6 months, "+str(FI12)+" in the last 12 months, and "+str(FI24)+"in the previous 24 months. "
        S5="(Reference: Chicago PMSA Foreclosure Inflows and Outflows, and Inventory figures)."
        paragraph = S1+S2+S3+S4+S5
        return paragraph

# %%
import os
import pandas as pd

PreMonth="February"
Month="February"
PostMonth="March"
PPstMonth="April"
PPPtMonth="May"
Year="2023"
PreYear="2023"
FI=2
FI6=6
FI12=12
FI24=24

os.chdir(r'C:\\Users\\Keitaro Ninomiya\\Box\\IAR_nino\\Results\Talking_Points\\Future_Condition')
TP1=pd.read_csv(Month+Year+"TP1.csv")
TP2=pd.read_csv(Month+Year+"TP2.csv")
TP3=pd.read_csv(Month+Year+"TP3.csv")
TP4=pd.read_csv(Month+Year+"TP4.csv")
TP5=pd.read_csv(Month+Year+"TP5.csv")

Paragraphs=HousingMarketFuture(Month, Year, TP1,TP2,TP3,TP4,TP5)
P1=Paragraphs.P1()
P2=Paragraphs.P2()
P3=Paragraphs.P3()
P4=Paragraphs.P4()
P5=Paragraphs.P5()
Draft=((Paragraphs.P1(),Paragraphs.P2(),Paragraphs.P3(),Paragraphs.P4(),Paragraphs.P5()))

# %%
os.chdir(r'C:\\Users\\Keitaro Ninomiya\\Box\\IAR_nino\\Report')
textfile = open("Future_Condition"+Month+Year+".txt", "w")
for element in Draft:
    textfile.write(element + "\n")
textfile.close()
